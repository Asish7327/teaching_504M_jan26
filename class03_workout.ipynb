# %% [markdown]
# ### Class 3 workout

# %%
# List manipulations

# %%
f = [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f[0])
# Out:
# 1

# %%
print(f[3])
# Out:
# 5

# %%
print(f[7])
# Out:
# last

# %%
print(f[8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f[8])
#
# IndexError: list index out of range

# %%
print(f[-1])
# Out:
# last

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f[1:8])
# Out:
# [2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
g = f[0:4]

# %%
print(g)
# Out:
# [1, 2.1, 3.2, 5]

# %%
print(f)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f[::2])
# Out:
# [1, 3.2, 'Ankita', True]

# %%
print(f[:])
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f[::-1][0:3][0])
# Out:
# last

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
f+f
# Out:
# [1,
#  2.1,
#  3.2,
#  5,
#  'Ankita',
#  'Hi',
#  True,
#  'last',
#  1,
#  2.1,
#  3.2,
#  5,
#  'Ankita',
#  'Hi',
#  True,
#  'last']

# %%
print(f+f)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
print(f+[1])
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1]

# %%
print(3*f)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
f.append(1)

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1]

# %%
del(f[-1])

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last']

# %%
f.append(1.1)

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1.1]

# %%
h=f

# %%
h
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1.1]

# %%
f.append(3.141)

# %%
print(f)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1.1, 3.141]

# %%
print(h)
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1.1, 3.141]

# %%
h=list(f)

# %%
h=f[:]

# %% [markdown]
# ## functions

# %%
def square_it(x):
    y=x**2
    return y

# %%
x=3

# %%
square_it(x= 7)
# Out:
# 49

# %%
def add_two_numbers(a, b):
    c = a+b
    return c

# %%
add_two_numbers(3, 4.5)
# Out:
# 7.5

# %%
type?
# Out:
# Init signature: type(self, /, *args, **kwargs)
# Docstring:
# type(object) -> the object's type
# type(name, bases, dict, **kwds) -> a new type
# Type:           type
# Subclasses:     ABCMeta, EnumType, _AnyMeta, NamedTupleMeta, _TypedDictMeta, _DeprecatedType, PyCStructType, UnionType, PyCPointerType, PyCArrayType, ...

# %%
help(type)
# Out:
# Help on class type in module builtins:
#
# class type(object)
#  |  type(object) -> the object's type
#  |  type(name, bases, dict, **kwds) -> a new type
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __dir__(self, /)
#  |      Specialized __dir__ implementation for types.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __instancecheck__(self, instance, /)
#  |      Check if an object is an instance.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __setattr__(self, name, value, /)
# ...

# %%
f
# Out:
# [1, 2.1, 3.2, 5, 'Ankita', 'Hi', True, 'last', 1.1, 3.141]

# %%
type(f)
# Out:
# list

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(f.reverse)
# Out:
# Help on built-in function reverse:
#
# reverse() method of builtins.list instance
#     Reverse *IN PLACE*.
