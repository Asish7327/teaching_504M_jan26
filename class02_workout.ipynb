# %% [markdown]
# ---- the file will be posted as is but refer to the class notes instead of this one ---

# %%
print("Hello Class")
# Out:
# Hello Class

# %%
print('Hi')
# Out:
# Hi

# %%
print(3+3*2+3*2)
# Out:
# 15

# %%
a=3

# %%
print(a)
# Out:
# 3

# %%
a
# Out:
# 3

# %%
print(a
# Out:
#   Cell In[16], line 1
#     print(a
#            ^
# SyntaxError: incomplete input

# %%
print(a**a)
# Out:
# 27

# %%
a=4

# %%
print(a)
# Out:
# 4

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b=4.5
c= "hi"
d= True
e = False

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print(type(d))
# Out:
# <class 'bool'>

# %%
list_a=[2, 3.141, 'Anjan', False]

# %%
print(type(list_a))
# Out:
# <class 'list'>

# %%
print(a*a)
# Out:
# 16

# %%
print(a*b)
# Out:
# 18.0

# %%
print(2*2.0)
# Out:
# 4.0

# %%
print(a/a)
# Out:
# 1.0

# %%
print(c+c)
# Out:
# hihi

# %%
x = '2'

# %%
print(x*x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(x*x)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
5%3
# Out:
# 2

# %%
8.99//3
# Out:
# 2.0

# %%
print(d)
# Out:
# True

# %% [raw]
# ---- the file will be posted as is but refer to the class notes instead of this one ---
