# %% [markdown]
# # Test 1 (Computational Physics - PH504M)
# * Date: 11 February 2026
# * Name:
# * Roll no.:

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Q1 - a) Answer

# %% [markdown]
# ### Q1 - b) Answer

# %% [markdown]
# ### Q1 - c) Answer

# %%
x = [0.0, 1.0, 2.0, 3.0, 4.0] 
y = [] # write from the question paper

# %% [markdown]
# ### Q1 - d) Answer

# %% [markdown]
# ### Q1 - e) Answer

# %%
x = [0.0, 0.2, 0.7, 1.5, 1.9, 2.6, 3.1, 3.9, 4.0]
y = [] # write from the question paper

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 - a) Answer

# %% [markdown]
# ### Q2 - b) Answer
