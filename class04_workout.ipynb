# %%
def subtract_two_numbers(a, b):
    """
    It subtracts two numbers a and b

    args: 
    a = number
    b = number

    returns:
    a-b
    
    """
    # c is the subtraction of a and b
    c = a - b
    return c

# %%
subtract_two_numbers(b= 1, a = 2)
# Out:
# 1

# %%
x = 1
y = 2
result = subtract_two_numbers(a=x, b=y)
print(result)
# Out:
# -1

# %%
subtract_two_numbers?
# Out:
# Signature: subtract_two_numbers(a, b)
# Docstring:
# It subtracts two numbers a and b
#
# args:
# a = number
# b = number
#
# returns:
# a-b
# File:      /tmp/ipykernel_627138/1389178602.py
# Type:      function

# %%
help(subtract_two_numbers)
# Out:
# Help on function subtract_two_numbers in module __main__:
#
# subtract_two_numbers(a, b)

# %% [markdown]
# ## Loops

# %%
a = 1.5
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")
# Out:
# Yessss .... a is bigger than b

# %%
a = 0.15
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")

# %%
a = 0.15
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")

if a<b:
    print("a is smaller than b")
# Out:
# a is smaller than b

# %%
a = 0.15
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")
else:
    print("a is smaller than b")
# Out:
# a is smaller than b

# %%
a = 0.5
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")
else:
    #print("a is smaller than or equal to b ... lets check")
    if a ==b:
        print("a and b are equal")
    else:
        print("a is smaller than b")
        
        
    #print("a is smaller than b")
# Out:
# a and b are equal

# %%
a = 0.5
b = 0.5
if a>b:
    print("Yessss .... a is bigger than b")
elif a<b:
    print("a is smaller than b")
else:
    print("a and b are equal")
# Out:
# a and b are equal

# %%
# alternate ways to == or !=
#if a is not b:
# if a is b:

# %% [markdown]
# ## For loops

# %%
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
range?
# Out:
# Init signature: range(self, /, *args, **kwargs)
# Docstring:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).
# Type:           type
# Subclasses:

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for j in range(10):
    print(j**2)
    #print('j+1 is', j+1)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
names = ["Upendra", "Shruti", "Ankit", "Aasha"]

# %%
for n in names:
    print(n)
# Out:
# Upendra
# Shruti
# Ankit
# Aasha

# %%
for i in range(4):
    print(names[i])
# Out:
# Upendra
# Shruti
# Ankit
# Aasha

# %%
colors = ["blue", "sky blue", "black", "peach"]

# %%
for n,c in zip(names, colors):
    print( n, 'likes', c)
# Out:
# Upendra likes blue
# Shruti likes sky blue
# Ankit likes black
# Aasha likes peach

# %%
zip?
# Out:
# Init signature: zip(self, /, *args, **kwargs)
# Docstring:
# zip(*iterables, strict=False) --> Yield tuples until an input is exhausted.
#
#    >>> list(zip('abcdefg', range(3), range(4)))
#    [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]
#
# The zip object yields n-length tuples, where n is the number of iterables
# passed as positional arguments to zip().  The i-th element in every tuple
# comes from the i-th iterable argument to zip().  This continues until the
# shortest argument is exhausted.
#
# If strict is true and one of the arguments is exhausted before the others,
# raise a ValueError.
# Type:           type
# Subclasses:

# %%
k = 1
while k <5:
    print(k)
    k = k + 1
# Out:
# 1
# 2
# 3
# 4
